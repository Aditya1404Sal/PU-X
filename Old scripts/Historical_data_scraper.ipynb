# %%
import time
import requests
import pandas as pd
import psycopg2
import logging
import os
from datetime import datetime
from io import StringIO
from concurrent.futures import ThreadPoolExecutor

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("data_collection.log"),
        logging.StreamHandler()
    ]
)

# Ensure directory exists
os.makedirs("historical_data", exist_ok=True)

# Database connection parameters
DB_PARAMS = {
    'dbname': 'Stock',
    'user': 'adity',
    'password': 'qwertypoi',
    'host': 'localhost'
}

# Session for NSE requests
session = requests.Session()

# Headers for NSE requests
head = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36",
    "Accept": "application/json, text/plain, */*",
    "Referer": "https://www.nseindia.com/",
}

def get_db_connection():
    """Establish a connection to the PostgreSQL database"""
    try:
        conn = psycopg2.connect(**DB_PARAMS)
        return conn
    except Exception as e:
        logging.error(f"Database connection error: {e}")
        return None

def fetch_stock_symbols():
    """Retrieve all stock symbols from the database"""
    conn = get_db_connection()
    if not conn:
        return []
    
    try:
        cursor = conn.cursor()
        cursor.execute("SELECT symbol FROM companies")
        symbols = [row[0] for row in cursor.fetchall()]
        cursor.close()
        conn.close()
        logging.info(f"Retrieved {len(symbols)} stock symbols from database")
        return symbols
    except Exception as e:
        logging.error(f"Error fetching symbols: {e}")
        if conn:
            conn.close()
        return []

def getHistoryData(company, from_date=None, to_date=None, save_csv=True):
    """Fetch historical data for a given company from NSE"""
    if from_date is None:
        from_date = datetime.today().strftime("%d-%m-%Y")
    if to_date is None:
        to_date = (datetime(datetime.today().year - 1, datetime.today().month, datetime.today().day).strftime("%d-%m-%Y"))

    try:
        # Initialize session with cookies
        session.get("https://www.nseindia.com", headers=head)
        session.get(f"https://www.nseindia.com/get-quotes/equity?symbol={company}", headers=head)
        session.get(f"https://www.nseindia.com/api/historical/cm/equity?symbol={company}", headers=head)

        # Fetch the data
        url = f"https://www.nseindia.com/api/historical/cm/equity?symbol={company}&series=[%22EQ%22]&from={to_date}&to={from_date}&csv=true"
        webdata = session.get(url, headers=head)

        if webdata.status_code != 200:
            logging.error(f"Failed to fetch data for {company}. Status Code: {webdata.status_code}")
            return None

        # Parse CSV data
        df = pd.read_csv(StringIO(webdata.text[3:]))  # Skipping the first three characters
        
        if save_csv:
            filename = f"historical_data/{company}.csv"
            df.to_csv(filename, index=False)
            logging.info(f"✅ Data saved: {filename}")
        
        return df
    except Exception as e:
        logging.error(f"❌ Error fetching data for {company}: {e}")
        return None

def process_symbol(symbol, from_date, to_date):
    """Process a single symbol to get its historical data"""
    try:
        logging.info(f"Processing symbol: {symbol}")
        data = getHistoryData(symbol, from_date, to_date)
        if data is not None:
            logging.info(f"Successfully retrieved data for {symbol} with {len(data)} records")
            return symbol, True
        return symbol, False
    except Exception as e:
        logging.error(f"Failed to process {symbol}: {e}")
        return symbol, False

def collect_all_historical_data(from_date=None, to_date=None, parallel=True, max_workers=5):
    """Collect historical data for all companies"""
    symbols = fetch_stock_symbols()
    
    if not symbols:
        logging.error("No symbols retrieved from the database")
        return
    
    successful = []
    failed = []
    
    if parallel:
        # Use thread pool for parallel processing
        with ThreadPoolExecutor(max_workers=max_workers) as executor:
            results = list(executor.map(
                lambda symbol: process_symbol(symbol, from_date, to_date), 
                symbols
            ))
        
        # Parse results
        successful = [symbol for symbol, success in results if success]
        failed = [symbol for symbol, success in results if not success]
    else:
        # Sequential processing
        for symbol in symbols:
            result = process_symbol(symbol, from_date, to_date)
            if result[1]:  # If successful
                successful.append(result[0])
            else:
                failed.append(result[0])
            
            # Add a small delay to avoid overloading the server
            time.sleep(1)
    
    # Report results
    logging.info(f"Data collection complete. Successful: {len(successful)}, Failed: {len(failed)}")
    if failed:
        logging.warning(f"Failed symbols: {failed}")
    
    return successful, failed

def save_results_to_db(successful, failed, from_date, to_date):
    """Save collection results to database for tracking"""
    conn = get_db_connection()
    if not conn:
        return False
    
    try:
        cursor = conn.cursor()
        
        # Create table if it doesn't exist
        cursor.execute("""
        CREATE TABLE IF NOT EXISTS collection_results (
            id SERIAL PRIMARY KEY,
            collection_date TIMESTAMP,
            from_date DATE,
            to_date DATE,
            successful_count INTEGER,
            failed_count INTEGER,
            successful_symbols TEXT[],
            failed_symbols TEXT[]
        )
        """)
        
        # Insert results
        cursor.execute("""
        INSERT INTO collection_results 
        (collection_date, from_date, to_date, successful_count, failed_count, successful_symbols, failed_symbols)
        VALUES (%s, %s, %s, %s, %s, %s, %s)
        """, (
            datetime.now(),
            datetime.strptime(from_date, "%d-%m-%Y").date() if from_date else None,
            datetime.strptime(to_date, "%d-%m-%Y").date() if to_date else None,
            len(successful),
            len(failed),
            successful,
            failed
        ))
        
        conn.commit()
        cursor.close()
        conn.close()
        logging.info("Collection results saved to database")
        return True
        
    except Exception as e:
        logging.error(f"Error saving results to database: {e}")
        if conn:
            conn.close()
        return False

if __name__ == "__main__":
    # Default dates - today to 1 year ago
    from_date = datetime.today().strftime("%d-%m-%Y")
    to_date = datetime(datetime.today().year - 1, datetime.today().month, datetime.today().day).strftime("%d-%m-%Y")
    
    # You can override these dates here
    # from_date = "14-04-2025"
    # to_date = "14-04-2024"
    
    logging.info(f"Starting data collection from {to_date} to {from_date}")
    
    # Collect data (using parallel processing by default)
    successful, failed = collect_all_historical_data(
        from_date=from_date,
        to_date=to_date,
        parallel=True,
        max_workers=5  # Adjust based on your system and to avoid rate limiting
    )
        
    logging.info("Script execution completed")
# Out:
# 2025-04-14 16:27:37,507 - INFO - Starting data collection from 14-04-2024 to 14-04-2025
# 2025-04-14 16:27:37,545 - INFO - Retrieved 2466 stock symbols from database
# 2025-04-14 16:27:37,546 - INFO - Processing symbol: 20MICRONS
# 2025-04-14 16:27:37,548 - INFO - Processing symbol: 21STCENMGM
# 2025-04-14 16:27:37,550 - INFO - Processing symbol: 360ONE
# 2025-04-14 16:27:37,550 - INFO - Processing symbol: 3IINFOLTD
# 2025-04-14 16:27:37,550 - INFO - Processing symbol: 3MINDIA
# 2025-04-14 16:27:38,481 - INFO - ✅ Data saved: historical_data/3IINFOLTD.csv
# 2025-04-14 16:27:38,482 - INFO - Successfully retrieved data for 3IINFOLTD with 248 records
# 2025-04-14 16:27:39,891 - INFO - ✅ Data saved: historical_data/AAREYDRUGS.csv
# 2025-04-14 16:27:39,891 - INFO - Successfully retrieved data for AAREYDRUGS with 87 records
# 2025-04-14 16:27:39,892 - INFO - Processing symbol: AARTIPHARM
# 2025-04-14 16:27:39,970 - INFO - ✅ Data saved: historical_data/AARON.csv
# 2025-04-14 16:27:39,971 - INFO - Successfully retrieved data for AARON with 248 records
# 2025-04-14 16:27:39,971 - INFO - Processing symbol: AARTISURF
# 2025-04-14 16:27:40,276 - INFO - ✅ Data saved: historical_data/AARTECH.csv
# 2025-04-14 16:27:40,277 - INFO - Successfully retrieved data for AARTECH with 110 records
# 2025-04-14 16:27:40,277 - INFO - Processing symbol: AARVEEDEN
# 2025-04-14 16:27:40,345 - INFO - ✅ Data saved: historical_data/AARTIDRUGS.csv
# 2025-04-14 16:27:40,345 - INFO - Successfully retrieved data for AARTIDRUGS with 248 records
# 2025-04-14 16:27:40,346 - INFO - Processing symbol: AARVI
# 2025-04-14 16:27:40,460 - INFO - ✅ Data saved: historical_data/AARTIIND.csv
# 2025-04-14 16:27:40,460 - INFO - Successfully retrieved data for AARTIIND with 248 records
# 2025-04-14 16:27:40,461 - INFO - Processing symbol: AATMAJ
# 2025-04-14 16:27:40,576 - INFO - ✅ Data saved: historical_data/AARTIPHARM.csv
# 2025-04-14 16:27:40,577 - INFO - Successfully retrieved data for AARTIPHARM with 248 records
# 2025-04-14 16:27:40,577 - INFO - Processing symbol: AAVAS
# 2025-04-14 16:27:40,658 - INFO - ✅ Data saved: historical_data/AARTISURF.csv
# 2025-04-14 16:27:40,659 - INFO - Successfully retrieved data for AARTISURF with 191 records
# 2025-04-14 16:27:40,659 - INFO - Processing symbol: ABAN
# 2025-04-14 16:27:41,070 - INFO - ✅ Data saved: historical_data/AATMAJ.csv
# 2025-04-14 16:27:41,071 - INFO - Successfully retrieved data for AATMAJ with 0 records
# 2025-04-14 16:27:41,071 - INFO - Processing symbol: ABB
# 2025-04-14 16:27:41,076 - INFO - ✅ Data saved: historical_data/AARVI.csv
# 2025-04-14 16:27:41,077 - INFO - Successfully retrieved data for AARVI with 248 records
# 2025-04-14 16:27:41,078 - INFO - Processing symbol: ABBOTINDIA
# 2025-04-14 16:27:41,402 - INFO - ✅ Data saved: historical_data/ABAN.csv
# 2025-04-14 16:27:41,403 - INFO - Successfully retrieved data for ABAN with 137 records
# 2025-04-14 16:27:41,403 - INFO - Processing symbol: ABHAPOWER
# 2025-04-14 16:27:41,590 - INFO - ✅ Data saved: historical_data/AAVAS.csv
# 2025-04-14 16:27:41,590 - INFO - Successfully retrieved data for AAVAS with 248 records
# 2025-04-14 16:27:41,591 - INFO - Processing symbol: ABMINTLLTD
# 2025-04-14 16:27:41,682 - INFO - ✅ Data saved: historical_data/ABB.csv
# 2025-04-14 16:27:41,683 - INFO - Successfully retrieved data for ABB with 248 records
# 2025-04-14 16:27:41,684 - INFO - Processing symbol: ABSMARINE
# 2025-04-14 16:27:41,727 - INFO - ✅ Data saved: historical_data/ABBOTINDIA.csv
# 2025-04-14 16:27:43,554 - INFO - Successfully retrieved data for ADANIENSOL with 248 records
# 2025-04-14 16:27:43,554 - INFO - Processing symbol: ATGL
# 2025-04-14 16:27:43,826 - INFO - ✅ Data saved: historical_data/ADANIGREEN.csv
# 2025-04-14 16:27:43,827 - INFO - Successfully retrieved data for ADANIGREEN with 248 records
# 2025-04-14 16:27:43,827 - INFO - Processing symbol: AWL
# 2025-04-14 16:27:43,909 - INFO - ✅ Data saved: historical_data/ADANIENT.csv
# 2025-04-14 16:27:43,910 - INFO - Successfully retrieved data for ADANIENT with 248 records
# 2025-04-14 16:27:43,910 - INFO - Processing symbol: LAWSIKHO
# 2025-04-14 16:27:43,917 - INFO - ✅ Data saved: historical_data/ADANIPORTS.csv
# 2025-04-14 16:27:43,918 - INFO - Successfully retrieved data for ADANIPORTS with 248 records
# 2025-04-14 16:27:43,918 - INFO - Processing symbol: ADFFOODS
# 2025-04-14 16:27:44,070 - INFO - ✅ Data saved: historical_data/ADANIPOWER.csv
# 2025-04-14 16:27:44,070 - INFO - Successfully retrieved data for ADANIPOWER with 248 records
# 2025-04-14 16:27:44,071 - INFO - Processing symbol: ABSLAMC
# 2025-04-14 16:27:44,211 - INFO - ✅ Data saved: historical_data/ATGL.csv
# 2025-04-14 16:27:44,211 - INFO - Successfully retrieved data for ATGL with 248 records
# 2025-04-14 16:27:44,211 - INFO - Processing symbol: ABCAPITAL
# 2025-04-14 16:27:44,454 - INFO - ✅ Data saved: historical_data/AWL.csv
# 2025-04-14 16:27:44,455 - INFO - Successfully retrieved data for AWL with 248 records
# 2025-04-14 16:27:44,455 - INFO - Processing symbol: ABFRL
# 2025-04-14 16:27:44,502 - INFO - ✅ Data saved: historical_data/LAWSIKHO.csv
# 2025-04-14 16:27:44,503 - INFO - Successfully retrieved data for LAWSIKHO with 0 records
# 2025-04-14 16:27:44,503 - INFO - Processing symbol: BIRLAMONEY
# 2025-04-14 16:27:44,513 - INFO - ✅ Data saved: historical_data/ADFFOODS.csv
# 2025-04-14 16:27:44,513 - INFO - Successfully retrieved data for ADFFOODS with 248 records
# 2025-04-14 16:27:44,514 - INFO - Processing symbol: ABREL
# 2025-04-14 16:27:44,749 - INFO - ✅ Data saved: historical_data/ABSLAMC.csv
# 2025-04-14 16:27:44,750 - INFO - Successfully retrieved data for ABSLAMC with 248 records
# 2025-04-14 16:27:44,750 - INFO - Processing symbol: AUSL
# 2025-04-14 16:27:44,932 - INFO - ✅ Data saved: historical_data/ABCAPITAL.csv
# 2025-04-14 16:27:44,932 - INFO - Successfully retrieved data for ABCAPITAL with 248 records
# 2025-04-14 16:27:44,933 - INFO - Processing symbol: AVL
# 2025-04-14 16:27:45,058 - INFO - ✅ Data saved: historical_data/ABFRL.csv
# 2025-04-14 16:27:45,058 - INFO - Successfully retrieved data for ABFRL with 248 records
# 2025-04-14 16:27:45,058 - INFO - Processing symbol: BSLGOLDETF
# 2025-04-14 16:27:45,170 - INFO - ✅ Data saved: historical_data/BIRLAMONEY.csv
# 2025-04-14 16:27:45,171 - INFO - Successfully retrieved data for BIRLAMONEY with 94 records
# 2025-04-14 16:27:45,171 - INFO - Processing symbol: BSLNIFTY
# 2025-04-14 16:27:45,381 - INFO - ✅ Data saved: historical_data/AUSL.csv
# 2025-04-14 16:27:45,382 - INFO - Successfully retrieved data for AUSL with 0 records
# 2025-04-14 16:27:45,383 - INFO - Processing symbol: ADROITINFO
# 2025-04-14 16:27:45,506 - INFO - ✅ Data saved: historical_data/ABREL.csv
# 2025-04-14 16:27:45,507 - INFO - Successfully retrieved data for ABREL with 248 records
# 2025-04-14 16:27:45,507 - INFO - Processing symbol: ADVENZYMES
# 2025-04-14 16:27:45,550 - INFO - ✅ Data saved: historical_data/AVL.csv
# 2025-04-14 16:27:45,551 - INFO - Successfully retrieved data for AVL with 107 records
# 2025-04-14 16:27:45,551 - INFO - Processing symbol: AMJUMBO
# 2025-04-14 16:27:45,677 - INFO - ✅ Data saved: historical_data/BSLGOLDETF.csv
# 2025-04-14 16:27:45,678 - INFO - Successfully retrieved data for BSLGOLDETF with 248 records
# 2025-04-14 16:27:45,679 - INFO - Processing symbol: ADVANIHOTR
# 2025-04-14 16:27:45,820 - INFO - ✅ Data saved: historical_data/BSLNIFTY.csv
# 2025-04-14 16:27:45,821 - INFO - Successfully retrieved data for BSLNIFTY with 248 records
# 2025-04-14 16:27:45,821 - INFO - Processing symbol: AEGISLOG
# 2025-04-14 16:27:46,115 - INFO - ✅ Data saved: historical_data/AMJUMBO.csv
# 2025-04-14 16:27:46,117 - INFO - Successfully retrieved data for AMJUMBO with 0 records
# 2025-04-14 16:27:46,119 - INFO - Processing symbol: AEROFLEX
# 2025-04-14 16:27:46,120 - INFO - ✅ Data saved: historical_data/ADVENZYMES.csv
# 2025-04-14 16:27:46,121 - INFO - Successfully retrieved data for ADVENZYMES with 248 records
# 2025-04-14 16:27:46,122 - INFO - Processing symbol: AERON
# 2025-04-14 16:27:46,132 - INFO - ✅ Data saved: historical_data/ADROITINFO.csv
# 2025-04-14 16:27:46,133 - INFO - Successfully retrieved data for ADROITINFO with 178 records
# 2025-04-14 16:27:46,134 - INFO - Processing symbol: AESTHETIK
# 2025-04-14 16:27:46,469 - INFO - ✅ Data saved: historical_data/AEGISLOG.csv
# 2025-04-14 16:27:46,470 - INFO - Successfully retrieved data for AEGISLOG with 248 records
# 2025-04-14 16:27:46,470 - INFO - Processing symbol: AETHER
# 2025-04-14 16:27:46,690 - INFO - ✅ Data saved: historical_data/AEROFLEX.csv
# 2025-04-14 16:27:46,691 - INFO - Successfully retrieved data for AEROFLEX with 248 records
# 2025-04-14 16:27:46,692 - INFO - Processing symbol: AFCONS
# 2025-04-14 16:27:46,795 - INFO - ✅ Data saved: historical_data/AESTHETIK.csv
# 2025-04-14 16:27:46,796 - INFO - Successfully retrieved data for AESTHETIK with 0 records
# 2025-04-14 16:27:46,797 - INFO - Processing symbol: AFFLE
# 2025-04-14 16:27:46,833 - INFO - ✅ Data saved: historical_data/AERON.csv
# 2025-04-14 16:27:46,840 - INFO - Successfully retrieved data for AERON with 0 records
# 2025-04-14 16:27:48,630 - INFO - ✅ Data saved: historical_data/AGROPHOS.csv
# 2025-04-14 16:27:48,631 - INFO - Successfully retrieved data for AGROPHOS with 248 records
# 2025-04-14 16:27:48,632 - INFO - Processing symbol: AIAENG
# 2025-04-14 16:27:48,703 - INFO - ✅ Data saved: historical_data/AGSTRA.csv
# 2025-04-14 16:27:48,703 - INFO - Successfully retrieved data for AGSTRA with 194 records
# 2025-04-14 16:27:48,704 - INFO - Processing symbol: AIMTRON
# 2025-04-14 16:27:48,919 - INFO - ✅ Data saved: historical_data/AHIMSA.csv
# 2025-04-14 16:27:48,920 - INFO - Successfully retrieved data for AHIMSA with 0 records
# 2025-04-14 16:27:48,920 - INFO - Processing symbol: GOLDTECH
# 2025-04-14 16:27:49,030 - INFO - ✅ Data saved: historical_data/AHLADA.csv
# 2025-04-14 16:27:49,031 - INFO - Successfully retrieved data for AHLADA with 185 records
# 2025-04-14 16:27:49,032 - INFO - Processing symbol: AIRAN
# 2025-04-14 16:27:49,106 - INFO - ✅ Data saved: historical_data/AHLUCONT.csv
# 2025-04-14 16:27:49,106 - INFO - Successfully retrieved data for AHLUCONT with 248 records
# 2025-04-14 16:27:49,107 - INFO - Processing symbol: AIROLAM
# 2025-04-14 16:27:49,242 - INFO - ✅ Data saved: historical_data/AIMTRON.csv
# 2025-04-14 16:27:49,243 - INFO - Successfully retrieved data for AIMTRON with 0 records
# 2025-04-14 16:27:49,243 - INFO - Processing symbol: AIRTELPP
# 2025-04-14 16:27:49,402 - INFO - ✅ Data saved: historical_data/AIAENG.csv
# 2025-04-14 16:27:49,402 - INFO - Successfully retrieved data for AIAENG with 248 records
# 2025-04-14 16:27:49,403 - INFO - Processing symbol: AJANTPHARM
# 2025-04-14 16:27:49,691 - INFO - ✅ Data saved: historical_data/GOLDTECH.csv
# 2025-04-14 16:27:49,692 - INFO - Successfully retrieved data for GOLDTECH with 149 records
# 2025-04-14 16:27:49,692 - INFO - Processing symbol: AJAXENGG
# 2025-04-14 16:27:49,719 - INFO - ✅ Data saved: historical_data/AIROLAM.csv
# 2025-04-14 16:27:49,720 - INFO - Successfully retrieved data for AIROLAM with 248 records
# 2025-04-14 16:27:49,720 - INFO - Processing symbol: AJMERA
# 2025-04-14 16:27:49,766 - INFO - ✅ Data saved: historical_data/AIRTELPP.csv
# 2025-04-14 16:27:49,767 - INFO - Successfully retrieved data for AIRTELPP with 0 records
# 2025-04-14 16:27:49,767 - INFO - Processing symbol: AJOONI
# 2025-04-14 16:27:49,793 - INFO - ✅ Data saved: historical_data/AIRAN.csv
# 2025-04-14 16:27:49,794 - INFO - Successfully retrieved data for AIRAN with 178 records
# 2025-04-14 16:27:49,794 - INFO - Processing symbol: AKANKSHA
# 2025-04-14 16:27:50,122 - INFO - ✅ Data saved: historical_data/AJANTPHARM.csv
# 2025-04-14 16:27:50,123 - INFO - Successfully retrieved data for AJANTPHARM with 248 records
# 2025-04-14 16:27:50,123 - INFO - Processing symbol: AKASH
# 2025-04-14 16:27:50,402 - INFO - ✅ Data saved: historical_data/AJMERA.csv
# 2025-04-14 16:27:57,327 - INFO - Successfully retrieved data for ANANDRATHI with 248 records
# 2025-04-14 16:27:57,327 - INFO - Processing symbol: ANDHRSUGAR
# 2025-04-14 16:27:57,369 - INFO - ✅ Data saved: historical_data/ANANTRAJ.csv
# 2025-04-14 16:27:57,370 - INFO - Successfully retrieved data for ANANTRAJ with 248 records
# 2025-04-14 16:27:57,370 - INFO - Processing symbol: ANGELONE
# 2025-04-14 16:27:57,624 - INFO - ✅ Data saved: historical_data/ACL.csv
# 2025-04-14 16:27:57,625 - INFO - Successfully retrieved data for ACL with 248 records
# 2025-04-14 16:27:57,625 - INFO - Processing symbol: AISL
# 2025-04-14 16:27:57,666 - INFO - ✅ Data saved: historical_data/AMEYA.csv
# 2025-04-14 16:27:57,667 - INFO - Successfully retrieved data for AMEYA with 0 records
# 2025-04-14 16:27:57,667 - INFO - Processing symbol: ANIKINDS
# 2025-04-14 16:27:58,010 - INFO - ✅ Data saved: historical_data/ANDHRSUGAR.csv
# 2025-04-14 16:27:58,011 - INFO - Successfully retrieved data for ANDHRSUGAR with 248 records
# 2025-04-14 16:27:58,011 - INFO - Processing symbol: APCL
# 2025-04-14 16:27:58,070 - INFO - ✅ Data saved: historical_data/ANDHRAPAP.csv
# 2025-04-14 16:27:58,071 - INFO - Successfully retrieved data for ANDHRAPAP with 248 records
# 2025-04-14 16:27:58,071 - INFO - Processing symbol: ANKITMETAL
# 2025-04-14 16:27:58,088 - INFO - ✅ Data saved: historical_data/ANGELONE.csv
# 2025-04-14 16:27:58,090 - INFO - Successfully retrieved data for ANGELONE with 248 records
# 2025-04-14 16:27:58,091 - INFO - Processing symbol: ANLON
# 2025-04-14 16:27:58,144 - INFO - ✅ Data saved: historical_data/AISL.csv
# 2025-04-14 16:27:58,145 - INFO - Successfully retrieved data for AISL with 0 records
# 2025-04-14 16:27:58,145 - INFO - Processing symbol: ANMOL
# 2025-04-14 16:27:58,361 - INFO - ✅ Data saved: historical_data/ANIKINDS.csv
# 2025-04-14 16:27:58,361 - INFO - Successfully retrieved data for ANIKINDS with 121 records
# 2025-04-14 16:27:58,362 - INFO - Processing symbol: ANNAPURNA
# 2025-04-14 16:27:58,648 - INFO - ✅ Data saved: historical_data/ANLON.csv
# 2025-04-14 16:27:58,650 - INFO - Successfully retrieved data for ANLON with 0 records
# 2025-04-14 16:27:58,650 - INFO - Processing symbol: ANSALAPI
# 2025-04-14 16:27:58,685 - INFO - ✅ Data saved: historical_data/APCL.csv
# 2025-04-14 16:27:58,686 - INFO - Successfully retrieved data for APCL with 248 records
# 2025-04-14 16:27:58,686 - INFO - Processing symbol: ANTGRAPHIC
# 2025-04-14 16:27:58,704 - INFO - ✅ Data saved: historical_data/ANKITMETAL.csv
# 2025-04-14 16:27:58,706 - INFO - Successfully retrieved data for ANKITMETAL with 15 records
# 2025-04-14 16:27:58,707 - INFO - Processing symbol: AWHCL
# 2025-04-14 16:27:58,785 - INFO - ✅ Data saved: historical_data/ANMOL.csv
# 2025-04-14 16:27:58,786 - INFO - Successfully retrieved data for ANMOL with 161 records
# 2025-04-14 16:27:58,787 - INFO - Processing symbol: ANUHPHR
# 2025-04-14 16:27:58,947 - INFO - ✅ Data saved: historical_data/ANNAPURNA.csv
# 2025-04-14 16:27:58,947 - INFO - Successfully retrieved data for ANNAPURNA with 0 records
# 2025-04-14 16:27:58,948 - INFO - Processing symbol: ANURAS
# 2025-04-14 16:27:59,320 - INFO - ✅ Data saved: historical_data/ANUHPHR.csv
# 2025-04-14 16:27:59,321 - INFO - ✅ Data saved: historical_data/ANSALAPI.csv
# 2025-04-14 16:27:59,321 - INFO - ✅ Data saved: historical_data/ANTGRAPHIC.csv
# 2025-04-14 16:27:59,321 - INFO - Successfully retrieved data for ANUHPHR with 77 records
# 2025-04-14 16:27:59,322 - INFO - Successfully retrieved data for ANSALAPI with 0 records
# 2025-04-14 16:27:59,323 - INFO - Successfully retrieved data for ANTGRAPHIC with 145 records
# 2025-04-14 16:27:59,323 - INFO - Processing symbol: ANYA
# 2025-04-14 16:27:59,324 - INFO - Processing symbol: APARINDS
# 2025-04-14 16:27:59,324 - INFO - Processing symbol: APCOTEXIND
# 2025-04-14 16:27:59,428 - INFO - ✅ Data saved: historical_data/AWHCL.csv
# 2025-04-14 16:27:59,428 - INFO - Successfully retrieved data for AWHCL with 248 records
# 2025-04-14 16:27:59,429 - INFO - Processing symbol: APEXECO
# 2025-04-14 16:27:59,694 - INFO - ✅ Data saved: historical_data/ANURAS.csv
# 2025-04-14 16:27:59,695 - INFO - Successfully retrieved data for ANURAS with 248 records
# 2025-04-14 16:27:59,696 - INFO - Processing symbol: APEX
# 2025-04-14 16:27:59,969 - INFO - ✅ Data saved: historical_data/ANYA.csv
# 2025-04-14 16:27:59,970 - INFO - Successfully retrieved data for ANYA with 0 records
# 2025-04-14 16:27:59,970 - INFO - Processing symbol: APLAPOLLO
# 2025-04-14 16:28:00,033 - INFO - ✅ Data saved: historical_data/APEXECO.csv
# 2025-04-14 16:28:00,034 - INFO - Successfully retrieved data for APEXECO with 0 records
# 2025-04-14 16:28:00,034 - INFO - Processing symbol: APOLLOHOSP
# 2025-04-14 16:28:00,098 - INFO - ✅ Data saved: historical_data/APCOTEXIND.csv
# 2025-04-14 16:28:00,099 - INFO - Successfully retrieved data for APCOTEXIND with 248 records
# 2025-04-14 16:28:00,099 - INFO - Processing symbol: APOLLO
# 2025-04-14 16:28:00,193 - INFO - ✅ Data saved: historical_data/APARINDS.csv
# 2025-04-14 16:28:00,195 - INFO - Successfully retrieved data for APARINDS with 248 records
# 2025-04-14 16:28:00,196 - INFO - Processing symbol: APOLLOPIPE
# 2025-04-14 16:28:00,412 - INFO - ✅ Data saved: historical_data/APEX.csv
# 2025-04-14 16:28:00,413 - INFO - Successfully retrieved data for APEX with 248 records
# 2025-04-14 16:28:00,414 - INFO - Processing symbol: APOLSINHOT
# 2025-04-14 16:28:00,584 - INFO - ✅ Data saved: historical_data/APLAPOLLO.csv
# 2025-04-14 16:28:00,585 - INFO - Successfully retrieved data for APLAPOLLO with 248 records
# 2025-04-14 16:28:00,585 - INFO - Processing symbol: APOLLOTYRE
# 2025-04-14 16:28:00,678 - INFO - ✅ Data saved: historical_data/APOLLO.csv
# 2025-04-14 16:28:00,678 - INFO - Successfully retrieved data for APOLLO with 243 records
# 2025-04-14 16:28:00,679 - INFO - Processing symbol: APRAMEYA
# 2025-04-14 16:28:00,815 - INFO - ✅ Data saved: historical_data/APOLLOHOSP.csv
# 2025-04-14 16:28:00,815 - INFO - Successfully retrieved data for APOLLOHOSP with 248 records
# 2025-04-14 16:28:00,816 - INFO - Processing symbol: APTECHT
# 2025-04-14 16:28:00,894 - INFO - ✅ Data saved: historical_data/APOLLOPIPE.csv
# 2025-04-14 16:28:00,895 - INFO - Successfully retrieved data for APOLLOPIPE with 248 records
# 2025-04-14 16:28:00,896 - INFO - Processing symbol: APTUS
# 2025-04-14 16:28:01,152 - INFO - ✅ Data saved: historical_data/APOLSINHOT.csv
# 2025-04-14 16:28:01,152 - INFO - Successfully retrieved data for APOLSINHOT with 248 records
# 2025-04-14 16:28:01,153 - INFO - Processing symbol: ARABIAN
# 2025-04-14 16:28:01,165 - INFO - ✅ Data saved: historical_data/APRAMEYA.csv
# 2025-04-14 16:28:01,166 - INFO - Successfully retrieved data for APRAMEYA with 0 records
# 2025-04-14 16:28:01,167 - INFO - Processing symbol: ACI
# 2025-04-14 16:28:01,235 - INFO - ✅ Data saved: historical_data/APOLLOTYRE.csv
# 2025-04-14 16:28:01,235 - INFO - Successfully retrieved data for APOLLOTYRE with 248 records
# 2025-04-14 16:28:01,236 - INFO - Processing symbol: ADL
# 2025-04-14 16:28:01,555 - INFO - ✅ Data saved: historical_data/APTECHT.csv
# 2025-04-14 16:28:01,556 - INFO - Successfully retrieved data for APTECHT with 248 records
# 2025-04-14 16:28:01,556 - INFO - Processing symbol: ARCHIDPLY
# 2025-04-14 16:28:01,742 - INFO - ✅ Data saved: historical_data/ARABIAN.csv
# 2025-04-14 16:28:01,743 - INFO - Successfully retrieved data for ARABIAN with 0 records
# 2025-04-14 16:28:01,743 - INFO - Processing symbol: ARCHIES
# 2025-04-14 16:28:01,769 - INFO - ✅ Data saved: historical_data/ACI.csv
# 2025-04-14 16:28:01,770 - INFO - Successfully retrieved data for ACI with 248 records
# 2025-04-14 16:28:01,771 - INFO - Processing symbol: ARHAM
# 2025-04-14 16:28:01,781 - INFO - ✅ Data saved: historical_data/ADL.csv
# 2025-04-14 16:28:01,782 - INFO - Successfully retrieved data for ADL with 177 records
# 2025-04-14 16:28:01,782 - INFO - Processing symbol: ARIES
# 2025-04-14 16:28:01,918 - INFO - ✅ Data saved: historical_data/APTUS.csv
# 2025-04-14 16:28:01,919 - INFO - Successfully retrieved data for APTUS with 248 records
# 2025-04-14 16:28:01,919 - INFO - Processing symbol: ARIHANTACA
# 2025-04-14 16:28:02,237 - INFO - ✅ Data saved: historical_data/ARCHIDPLY.csv
# 2025-04-14 16:28:02,237 - INFO - Successfully retrieved data for ARCHIDPLY with 152 records
# 2025-04-14 16:28:02,238 - INFO - Processing symbol: ARIHANTCAP
